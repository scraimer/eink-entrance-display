# %%
import layout
import scrape
from layout import make_image

# reload modules in Jupyter
import importlib
importlib.reload(display)
importlib.reload(layout)
importlib.reload(scrape)

from IPython import display

image = make_image()
display.display(display.Image(filename='color.png'))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): reshitd.wixsite.com:443
# DEBUG:urllib3.connectionpool:https://reshitd.wixsite.com:443 "GET /home/zmanim HTTP/1.1" 200 None
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 54 4
# DEBUG:PIL.PngImagePlugin:STREAM b'PLTE' 70 6
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 88 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 109 116
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 54 4
# DEBUG:PIL.PngImagePlugin:STREAM b'PLTE' 70 6
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 88 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 109 179
